# %%
import pandas as pd

# Define data for companies
data = {
    "Industry": ["Automobile", "Automobile", "Automobile", "Automobile", "Automobile",
                 "Information Technology", "Information Technology", "Information Technology", "Information Technology", "Information Technology",
                 "Pharmaceuticals", "Pharmaceuticals", "Pharmaceuticals", "Pharmaceuticals", "Pharmaceuticals",
                 "FMCG", "FMCG", "FMCG", "FMCG", "FMCG",
                 "Energy", "Energy", "Energy", "Energy", "Energy"],
    "Company": ["Maruti Suzuki", "Tata Motors", "Mahindra & Mahindra", "Bajaj Auto", "Hero MotoCorp",
                "Tata Consultancy Services", "Infosys", "Wipro", "HCL Technologies", "Tech Mahindra",
                "Sun Pharmaceutical", "Dr. Reddy's Laboratories", "Cipla", "Lupin", "Aurobindo Pharma",
                "Hindustan Unilever", "ITC", "Nestle India", "Britannia Industries", "Dabur India",
                "Reliance Industries", "ONGC", "Indian Oil Corporation", "Bharat Petroleum", "GAIL India"],
    "Current Price (INR)": [8800, 400, 1300, 4000, 2600, 
                            3200, 1450, 410, 1150, 1050,
                            900, 4500, 1000, 820, 700,
                            2400, 350, 20500, 3700, 560,
                            2500, 155, 100, 370, 125],
    "P/E Ratio": [30, 18, 25, 22, 28, 
                  32, 29, 20, 24, 23,
                  20, 18, 25, 22, 21,
                  50, 28, 80, 42, 30,
                  35, 10, 15, 12, 18]
}

# Define data for banks
bank_data = {
    "Bank": ["Kotak Mahindra Bank", "HDFC Bank", "ICICI Bank", "State Bank of India", "Canara Bank"],
    "Current Price (INR)": [1850, 1600, 920, 570, 330],
    "P/B Ratio": [4.0, 3.2, 3.5, 1.5, 0.8]
}

# Create DataFrames
df_companies = pd.DataFrame(data)
df_banks = pd.DataFrame(bank_data)

# Calculate EPS for companies
df_companies['EPS (INR)'] = df_companies['Current Price (INR)'] / df_companies['P/E Ratio']

# Calculate BVPS for banks
df_banks['BVPS (INR)'] = df_banks['Current Price (INR)'] / df_banks['P/B Ratio']

# Display the tables with EPS and BVPS
print("Companies Data with EPS:")
print(df_companies[['Industry', 'Company', 'Current Price (INR)', 'P/E Ratio', 'EPS (INR)']])

print("\nBanks Data with BVPS:")
print(df_banks[['Bank', 'Current Price (INR)', 'P/B Ratio', 'BVPS (INR)']])
# Out:
# Companies Data with EPS:
#                   Industry                    Company  Current Price (INR)  \
# 0               Automobile              Maruti Suzuki                 8800
# 1               Automobile                Tata Motors                  400
# 2               Automobile        Mahindra & Mahindra                 1300
# 3               Automobile                 Bajaj Auto                 4000
# 4               Automobile              Hero MotoCorp                 2600
# 5   Information Technology  Tata Consultancy Services                 3200
# 6   Information Technology                    Infosys                 1450
# 7   Information Technology                      Wipro                  410
# 8   Information Technology           HCL Technologies                 1150
# 9   Information Technology              Tech Mahindra                 1050
# 10         Pharmaceuticals         Sun Pharmaceutical                  900
# ...
